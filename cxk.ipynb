# %% [markdown]
# <a href="https://colab.research.google.com/github/EncodingDavid/tensorflow/blob/master/cxk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
img_origin = cv2.imread('cxk.jpeg')
cv2_imshow(img_origin)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F8114507F98>

# %%
img_gray = cv2.cvtColor(img_origin, cv2.COLOR_RGB2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F81124BF320>

# %%
img_blurred = cv2.GaussianBlur(img_gray, (5, 5), 0)
cv2_imshow(img_blurred)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F81124BF3C8>

# %%
img_threshold1 = cv2.adaptiveThreshold(img_blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 5, 2)
cv2_imshow(img_threshold1)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F81124C4518>

# %%
img_threshold1_blurred = cv2.GaussianBlur(img_threshold1, (5, 5), 0)
cv2_imshow(img_threshold1_blurred)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F81124B5C50>

# %%
_, img_threshold2 = cv2.threshold(img_threshold1_blurred, 200, 255, cv2.THRESH_BINARY)
cv2_imshow(img_threshold2)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F81144E7D30>

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(3, 3))
img_opening = cv2.bitwise_not(cv2.morphologyEx(cv2.bitwise_not(img_threshold2), cv2.MORPH_OPEN, kernel))
cv2_imshow(img_opening)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F8114507A58>

# %%
img_opening_blurred = cv2.GaussianBlur(img_opening, (3, 3), 0)
cv2_imshow(img_opening_blurred)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F811450C240>
